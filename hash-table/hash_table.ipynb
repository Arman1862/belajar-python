# %% [markdown]
# # Hash Table - Python Implementation

# %%
class HashTable:
  def __init__(self,size):
    self.size = size
    self.table = {}
    for i in range(size):
      self.table[i] = []
  
  def hash(self,key):
    return key % self.size
  
  def get(self,key):
    return self.table[self.hash(key)]
  
  def put(self,key,value):
    bucket = self.table[self.hash(key)]
    if value not in bucket:
      bucket.append(value)

# %% [markdown]
# Detail penjelasan untuk class di atas berdasarkan fungsinya :
#
# - `def __init__(self,size) dan def hash(self,key)`
#
# Parameter size sebagai input adalah ukuran hash table dan hash table didefinisikan oleh tipe data dictionary dalam Python. Di dalam dictionary tersebut, kita menginisialisasikan list kosong ke masing-masing bucket.
#
# - `def put(self,key,value)`
#
# Kemudian, temukan bucket di mana key value-nya adalah self.hash(key) dalam dictionary self.table. Ketika duplikasi tidak diperbolehkan, tambahkan value dalam bucket hanya jika bucket tidak memiliki value tersebut.
#
# - `def get(self,key)`
#
# Kembalikan bucket di mana key valuenya adalah self.hash(key) dalam dictionary self.table.
#
# Berikut contoh penerapannya dalam kode sederhana:

# %%
table = HashTable(8) # inisialisasi instance table dengan size 8 
books = [
  "The Little Prince",
  "The Old Man and the Sea",
  "The Little Mermaid",
  "Beauty and the Beast",
  "The Last Leaf",
]
for book in books: # iterasi semua buku
  key = sum(map(ord,book))
  table.put(key,book)

for key in table.table.keys():
  print(key, table.table[key])
# Out:
# 0 ['The Little Prince']
# 1 ['The Old Man and the Sea']
# 2 []
# 3 []
# 4 []
# 5 ['Beauty and the Beast', 'The Last Leaf']
# 6 ['The Little Mermaid']
# 7 []

# %% [markdown]
# Dari kode di atas kita berhasil menyimpan seluruh 5 buku dengan key-nya ke dalam rak yang memiliki slot 8, untuk mencari slot buku `The Last Leaf`, kita bisa menggunakan method `get` yang sudah kita deklarasikan di dalam `class`.

# %%
judul = 'The Last Leaf'
key = sum(map(ord,judul))
bucket = table.get(key)
print(key,bucket)
# Out:
# 1133 ['Beauty and the Beast', 'The Last Leaf']
